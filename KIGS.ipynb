# %% [markdown]
# basic info:
# - restarts
# - SHARED RESOURCE
# - Jupyterhub bad (imo)
# - proper IDEs exist lmao
#
# connection via SSH console
#
# connection via jetbrains toolbox
#
# nvidia-smi
#
# virtual environments
#
# nvtop
# - figuring out process ids
# - killing processes
# - annoying people who waste memory to kill their processes

# %% [markdown]
# show how cool quantized models are by demonstrating those commands in a live demo
